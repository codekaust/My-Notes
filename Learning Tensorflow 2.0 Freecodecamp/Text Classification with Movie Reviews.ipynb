# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
data = keras.datasets.imdb

# %%
((train_data, train_labels), (test_data, test_labels)) = data.load_data(num_words=10000)

# %%
word_index = data.get_word_index()

# %%
# shifts all numbers by three required for the next cell 0 is already free only
word_index = {k:(v+3) for k,v in word_index.items()}

# %%
# this is in accordance with the keras.datasets.imdb

word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2
word_index["<UNUSED>"] = 3

# %%
reversed_word_index = dict([(val, key) for (key, val) in word_index.items()])
#  or {val: key for key, val in word_index.items()}

# %%
def decode_review(text):
    return " ".join([reversed_word_index.get(i, "?") for i in text])

# example
print(test_data[5])
print(decode_review(test_data[0]))
# Out:
# [1, 146, 427, 5718, 14, 20, 218, 112, 2962, 32, 37, 119, 14, 20, 144, 9493, 910, 5, 8817, 4, 4659, 18, 12, 3403, 853, 28, 8, 2225, 12, 95, 474, 818, 4651, 18, 1462, 13, 124, 285, 5, 1462, 11, 14, 20, 122, 6, 52, 292, 5, 13, 774, 2626, 46, 138, 910, 1481, 276, 14, 20, 23, 288, 42, 23, 1856, 11, 2364, 5687, 33, 222, 13, 774, 110, 101, 4651, 14, 9, 6, 3799, 52, 20, 5, 144, 30, 110, 34, 32, 4, 362, 11, 4, 162, 2248, 92, 79, 8, 67, 12, 5, 13, 104, 36, 144, 12, 144, 33, 222, 30, 276, 145, 23, 4, 1308, 14, 20, 152, 1833, 6, 706, 2, 12, 1015, 4, 147, 155, 146, 98, 150, 14, 20, 80, 30, 23, 288]
# <START> please give this one a miss br br <UNK> <UNK> and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite <UNK> so all you madison fans give this a miss

# %%
# notice difference in lenghts of different review's lengths

print(len(test_data[0]))
print(len(test_data[1]))
print(len(test_data[2]))
print(len(test_data[3]))
# Out:
# 68
# 260
# 603
# 181

# %%
# using padding length as 250 (can be set to max len(test_data[i])) also

# you can also do bottom with simple for loops
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value = word_index["<PAD>"], padding = "post", maxlen=250)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value = word_index["<PAD>"], padding = "post", maxlen=250)

# now length same
print(len(test_data[0]))
print(len(test_data[1]))
print(len(test_data[2]))
print(len(test_data[3]))
# Out:
# 250
# 250
# 250
# 250

# %%
# model

model = keras.Sequential()
model.add(keras.layers.Embedding(10000,16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

x_val = train_data[:10000]
x_train = train_data[10000:]


y_val = train_labels[:10000]
y_train = train_labels[10000:]

# %%
fitModel = model.fit(x_train, y_train, epochs=50, batch_size=512, validation_data=(x_val, y_val), verbose = 1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/50
# 15000/15000 [==============================] - 1s 80us/sample - loss: 0.6923 - accuracy: 0.5557 - val_loss: 0.6906 - val_accuracy: 0.7054
# Epoch 2/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.6874 - accuracy: 0.7228 - val_loss: 0.6837 - val_accuracy: 0.7354
# Epoch 3/50
# 15000/15000 [==============================] - 1s 34us/sample - loss: 0.6768 - accuracy: 0.7577 - val_loss: 0.6698 - val_accuracy: 0.7476
# Epoch 4/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.6566 - accuracy: 0.7679 - val_loss: 0.6459 - val_accuracy: 0.7727
# Epoch 5/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.6245 - accuracy: 0.7898 - val_loss: 0.6113 - val_accuracy: 0.7741
# Epoch 6/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.5826 - accuracy: 0.8064 - val_loss: 0.5694 - val_accuracy: 0.7969
# Epoch 7/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.5342 - accuracy: 0.8279 - val_loss: 0.5250 - val_accuracy: 0.8187
# Epoch 8/50
# 15000/15000 [==============================] - 0s 32us/sample - loss: 0.4853 - accuracy: 0.8448 - val_loss: 0.4818 - val_accuracy: 0.8283
# Epoch 9/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.4397 - accuracy: 0.8587 - val_loss: 0.4435 - val_accuracy: 0.8409
# Epoch 10/50
# 15000/15000 [==============================] - 1s 33us/sample - loss: 0.3993 - accuracy: 0.8712 - val_loss: 0.4121 - val_accuracy: 0.8514
# Epoch 11/50
# 15000/15000 [==============================] - 1s 34us/sample - loss: 0.3656 - accuracy: 0.8813 - val_loss: 0.3863 - val_accuracy: 0.8568
# Epoch 12/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.3370 - accuracy: 0.8884 - val_loss: 0.3659 - val_accuracy: 0.8624
# Epoch 13/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.3136 - accuracy: 0.8932 - val_loss: 0.3493 - val_accuracy: 0.8662
# Epoch 14/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.2935 - accuracy: 0.9004 - val_loss: 0.3369 - val_accuracy: 0.8687
# Epoch 15/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.2766 - accuracy: 0.9051 - val_loss: 0.3252 - val_accuracy: 0.8745
# Epoch 16/50
# 15000/15000 [==============================] - 1s 35us/sample - loss: 0.2607 - accuracy: 0.9102 - val_loss: 0.3167 - val_accuracy: 0.8776
# Epoch 17/50
# 15000/15000 [==============================] - 0s 32us/sample - loss: 0.2467 - accuracy: 0.9133 - val_loss: 0.3094 - val_accuracy: 0.8799
# Epoch 18/50
# 15000/15000 [==============================] - 0s 29us/sample - loss: 0.2346 - accuracy: 0.9189 - val_loss: 0.3036 - val_accuracy: 0.8813
# Epoch 19/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.2229 - accuracy: 0.9231 - val_loss: 0.3002 - val_accuracy: 0.8804
# Epoch 20/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.2126 - accuracy: 0.9261 - val_loss: 0.2953 - val_accuracy: 0.8829
# Epoch 21/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.2029 - accuracy: 0.9307 - val_loss: 0.2939 - val_accuracy: 0.8810
# Epoch 22/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.1941 - accuracy: 0.9346 - val_loss: 0.2894 - val_accuracy: 0.8839
# Epoch 23/50
# 15000/15000 [==============================] - 1s 35us/sample - loss: 0.1857 - accuracy: 0.9389 - val_loss: 0.2877 - val_accuracy: 0.8850
# Epoch 24/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.1783 - accuracy: 0.9417 - val_loss: 0.2861 - val_accuracy: 0.8852
# Epoch 25/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.1703 - accuracy: 0.9450 - val_loss: 0.2853 - val_accuracy: 0.8856
# Epoch 26/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.1633 - accuracy: 0.9479 - val_loss: 0.2848 - val_accuracy: 0.8852
# Epoch 27/50
# 15000/15000 [==============================] - 0s 32us/sample - loss: 0.1566 - accuracy: 0.9513 - val_loss: 0.2850 - val_accuracy: 0.8861
# Epoch 28/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.1504 - accuracy: 0.9533 - val_loss: 0.2855 - val_accuracy: 0.8855
# Epoch 29/50
# 15000/15000 [==============================] - 0s 32us/sample - loss: 0.1444 - accuracy: 0.9558 - val_loss: 0.2854 - val_accuracy: 0.8862
# Epoch 30/50
# 15000/15000 [==============================] - 0s 31us/sample - loss: 0.1387 - accuracy: 0.9586 - val_loss: 0.2864 - val_accuracy: 0.8863
# Epoch 31/50
# 15000/15000 [==============================] - 0s 30us/sample - loss: 0.1332 - accuracy: 0.9606 - val_loss: 0.2876 - val_accuracy: 0.8857
# Epoch 32/50
# 15000/15000 [==============================] - 0s 32us/sample - loss: 0.1281 - accuracy: 0.9627 - val_loss: 0.2891 - val_accuracy: 0.8870
# Epoch 33/50
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.1237 - accuracy: 0.9644 - val_loss: 0.2910 - val_accuracy: 0.8869
# Epoch 34/50
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.1187 - accuracy: 0.9663 - val_loss: 0.2941 - val_accuracy: 0.8835
# Epoch 35/50
# 15000/15000 [==============================] - 1s 47us/sample - loss: 0.1146 - accuracy: 0.9683 - val_loss: 0.2961 - val_accuracy: 0.8845
# Epoch 36/50
# 15000/15000 [==============================] - 1s 53us/sample - loss: 0.1100 - accuracy: 0.9700 - val_loss: 0.2980 - val_accuracy: 0.8848
# Epoch 37/50
# 15000/15000 [==============================] - 1s 73us/sample - loss: 0.1058 - accuracy: 0.9703 - val_loss: 0.2998 - val_accuracy: 0.8853
# Epoch 38/50
# 15000/15000 [==============================] - 1s 69us/sample - loss: 0.1018 - accuracy: 0.9732 - val_loss: 0.3037 - val_accuracy: 0.8833
# Epoch 39/50
# 15000/15000 [==============================] - 1s 71us/sample - loss: 0.0982 - accuracy: 0.9742 - val_loss: 0.3053 - val_accuracy: 0.8832
# Epoch 40/50
# 15000/15000 [==============================] - 1s 74us/sample - loss: 0.0941 - accuracy: 0.9761 - val_loss: 0.3087 - val_accuracy: 0.8829
# Epoch 41/50
# 15000/15000 [==============================] - 1s 68us/sample - loss: 0.0910 - accuracy: 0.9771 - val_loss: 0.3135 - val_accuracy: 0.8811
# Epoch 42/50
# 15000/15000 [==============================] - 1s 69us/sample - loss: 0.0878 - accuracy: 0.9785 - val_loss: 0.3154 - val_accuracy: 0.8827
# Epoch 43/50
# 15000/15000 [==============================] - 1s 65us/sample - loss: 0.0845 - accuracy: 0.9793 - val_loss: 0.3188 - val_accuracy: 0.8821
# Epoch 44/50
# 15000/15000 [==============================] - 1s 67us/sample - loss: 0.0806 - accuracy: 0.9813 - val_loss: 0.3224 - val_accuracy: 0.8816
# Epoch 45/50
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.0776 - accuracy: 0.9827 - val_loss: 0.3270 - val_accuracy: 0.8810
# Epoch 46/50
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.0749 - accuracy: 0.9827 - val_loss: 0.3305 - val_accuracy: 0.8810
# Epoch 47/50
# 15000/15000 [==============================] - 1s 66us/sample - loss: 0.0725 - accuracy: 0.9831 - val_loss: 0.3348 - val_accuracy: 0.8805
# Epoch 48/50
# 15000/15000 [==============================] - 1s 60us/sample - loss: 0.0694 - accuracy: 0.9845 - val_loss: 0.3396 - val_accuracy: 0.8793
# Epoch 49/50
# 15000/15000 [==============================] - 1s 70us/sample - loss: 0.0665 - accuracy: 0.9858 - val_loss: 0.3431 - val_accuracy: 0.8785
# Epoch 50/50
# 15000/15000 [==============================] - 1s 66us/sample - loss: 0.0643 - accuracy: 0.9863 - val_loss: 0.3474 - val_accuracy: 0.8783

# %%
results = model.evaluate(test_data, test_labels)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
results
# Out:
# [0.37322977763652804, 0.86604]

# %%
k=0
l=1000

for i in range(l):
    predict = model.predict([test_data[i]])

#     print("Review: " + decode_review(test_data[i]))
#     print("Prediction: " +str(predict[i]))
#     print("Actual: "+str(test_labels[i]))
    
    if predict[0] == test_labels[i]:
        k+=1

# %%
print(k/l)
# Out:
# 0.44
